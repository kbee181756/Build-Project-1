# %% [markdown]
# <a href="https://colab.research.google.com/github/kbee181756/Build-Project-1/blob/master/228project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url_1 = ('https://raw.githubusercontent.com/kbee181756/Build-Project-1/master/LocationMaster.csv?token=AD456YXIQXFXK4SLLFTBIAK6MHDAC')
url_2 = ('https://raw.githubusercontent.com/kbee181756/Build-Project-1/master/demographics.csv?token=AD456YXZMCQAPVYH5K4YXSS6MHDOK')

# %%
location = pd.DataFrame(pd.read_csv(url_1))
data = pd.DataFrame(pd.read_csv(url_2))

# %%
location_data = pd.DataFrame(pd.merge(data, location, left_on='DBN', right_on='ATS System Code'))

# %%
def get_first_three(sequence):
  return sequence[:3]

# %%
location_data['first_three'] = location_data['DBN'].apply(get_first_three)

# %%
location_data_up = pd.DataFrame(location_data.drop(['Unnamed: 21', 
                      'Unnamed: 22',
                      'Unnamed: 23',
                      'Unnamed: 24',
                      'Unnamed: 25',
                      'Unnamed: 26',
                      'Unnamed: 27',
                      'Unnamed: 28',
                      'Unnamed: 29',
                      'Unnamed: 30',
                      'Unnamed: 31',
                      'Unnamed: 32',
                      'Unnamed: 33',
                      'Unnamed: 34',
                      'Unnamed: 35',
                      'Unnamed: 36',
                      'Unnamed: 37',
                      'Unnamed: 38',
                      'Unnamed: 39', 
                      'Unnamed: 40',
                      'Unnamed: 41',
                      'Unnamed: 42',
                      'Unnamed: 43',
                      'Unnamed: 44',
                      'Status Description',
                      'Building Code',
                      'Managed By Name',
                      'Location Code',
                      'BEDS Number',
                      'Location Type Description',
                      'Grades Final',
                      'Administrative District Location Code',
                      'Administrative District Name'], axis = 1))

# %%
location_data_up
# Out:
#          DBN  ... first_three
# 0     01M015  ...         01M
# 1     01M015  ...         01M
# 2     01M015  ...         01M
# 3     01M015  ...         01M
# 4     01M015  ...         01M
# ...      ...  ...         ...
# 7383  84X730  ...         84X
# 7384  84X730  ...         84X
# 7385  84X730  ...         84X
# 7386  84X730  ...         84X
# 7387  84X730  ...         84X
#
# [7388 rows x 52 columns]

# %%
data2017_18 = pd.DataFrame(location_data_up[location_data_up['Year'] =='2017-18'])

# %%
data2017_18
# Out:
#          DBN  ... first_three
# 4     01M015  ...         01M
# 9     01M019  ...         01M
# 14    01M020  ...         01M
# 19    01M034  ...         01M
# 24    01M063  ...         01M
# ...      ...  ...         ...
# 7367  84X705  ...         84X
# 7372  84X706  ...         84X
# 7377  84X717  ...         84X
# 7382  84X718  ...         84X
# 7387  84X730  ...         84X
#
# [1478 rows x 52 columns]

# %%
elementary_all = pd.DataFrame(data2017_18[data2017_18['Location Category Description'] == 'Elementary'])

# %%
elementary_all
# Out:
#          DBN  ... first_three
# 4     01M015  ...         01M
# 9     01M019  ...         01M
# 14    01M020  ...         01M
# 24    01M063  ...         01M
# 29    01M064  ...         01M
# ...      ...  ...         ...
# 7352  84X422  ...         84X
# 7367  84X705  ...         84X
# 7377  84X717  ...         84X
# 7382  84X718  ...         84X
# 7387  84X730  ...         84X
#
# [649 rows x 52 columns]

# %%
elementary_brooklyn = pd.DataFrame(data2017_18[data2017_18['City'] == 'BROOKLYN'])

# %%
elementary_brooklyn
# Out:
#          DBN  ... first_three
# 2869  13K003  ...         13K
# 2874  13K008  ...         13K
# 2879  13K009  ...         13K
# 2884  13K011  ...         13K
# 2889  13K020  ...         13K
# ...      ...  ...         ...
# 7097  84K652  ...         84K
# 7102  84K701  ...         84K
# 7107  84K702  ...         84K
# 7112  84K704  ...         84K
# 7117  84K731  ...         84K
#
# [448 rows x 52 columns]

# %%
elementary2017_18 = pd.DataFrame(elementary_all.drop(axis=1, columns=['Grade PK (Half Day & Full Day)', 'Grade K', 'Grade 1', 'Grade 2', 
                                     'Grade 3', 'Grade 4', 'Grade 5', 'Grade 6', 'Grade 7', 'Grade 8', 'Grade 9', 
                                     'Grade 10', 'Grade 11', 'Grade 12']))

# %%
elementary_brooklyn_district_13 = elementary2017_18[elementary2017_18['first_three'] == '13K']

# %%
elementary_brooklyn_district_13
# Out:
#          DBN  ... first_three
# 2869  13K003  ...         13K
# 2874  13K008  ...         13K
# 2879  13K009  ...         13K
# 2884  13K011  ...         13K
# 2889  13K020  ...         13K
# 2894  13K044  ...         13K
# 2899  13K046  ...         13K
# 2904  13K054  ...         13K
# 2909  13K056  ...         13K
# 2914  13K067  ...         13K
# 2919  13K093  ...         13K
# 2929  13K133  ...         13K
# 2934  13K256  ...         13K
# 2949  13K270  ...         13K
# 2954  13K282  ...         13K
# 2959  13K287  ...         13K
# 2964  13K301  ...         13K
# 2969  13K305  ...         13K
# 2974  13K307  ...         13K
#
# [19 rows x 38 columns]

# %%
school_names_13 = elementary_brooklyn_district_13['School Name'].to_list()

# %%
school_names_13
# Out:
# ['P.S. 003 The Bedford Village',
#  'P.S. 008 Robert Fulton',
#  'P.S. 009 Teunis G. Bergen',
#  'P.S. 011 Purvis J. Behan',
#  'P.S. 020 Clinton Hill',
#  'P.S. 044 Marcus Garvey',
#  'P.S. 046 Edward C. Blum',
#  'P.S. 054 Samuel C. Barnes',
#  'P.S. 056 Lewis H. Latimer',
#  'P.S. 067 Charles A. Dorsey',
#  'P.S. 093 William H. Prescott',
#  'P.S. 133 William A. Butler',
#  'P.S. 256 Benjamin Banneker',
#  'P.S. 270 Johann DeKalb',
#  'P.S. 282 Park Slope',
#  'P.S. 287 Bailey K. Ashford',
#  'Satellite East Middle School',
#  'P.S. 305 Dr. Peter Ray',
#  'P.S. 307 Daniel Hale Williams']

# %%
f, (ax1) = plt.subplots(1, 1, figsize=(7, 5), sharex=True)
x = np.array(list(school_names_13))

# %%
y_13_elem = pd.DataFrame(elementary_brooklyn_district_13['Total Enrollment'].to_list())

# %%
sns.set(style='whitegrid')
ax = sns.barplot(x='school_names_13', y='y_13_elem', data=elementary_brooklyn_district_13['y_13_elem'])

# %%
#@title Default title text
chart = sns.lineplot(data=y_13_elem)

# %%
y_13_elem.plot(kind="bar", figsize=(15,5));

# %%
y_13_elem.mean()
# Out:
# 0    396.789474
# dtype: float64
