# %% [markdown]
# <a href="https://colab.research.google.com/github/kbee181756/Build-Project-1/blob/master/228_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url_1 = ('https://raw.githubusercontent.com/kbee181756/Build-Project-1/master/LocationMaster.csv?token=AD456YXIQXFXK4SLLFTBIAK6MHDAC')
url_2 = ('https://raw.githubusercontent.com/kbee181756/Build-Project-1/master/demographics.csv?token=AD456YXZMCQAPVYH5K4YXSS6MHDOK')

# %%
location = pd.DataFrame(pd.read_csv(url_1))
data = pd.DataFrame(pd.read_csv(url_2))

# %%
location_data = pd.DataFrame(pd.merge(data, location, left_on='DBN', right_on='ATS System Code'))

# %%
location_data
# Out:
#          DBN                        School Name  ... Unnamed: 43  Unnamed: 44
# 0     01M015          P.S. 015 Roberto Clemente  ...         NaN          NaN
# 1     01M015          P.S. 015 Roberto Clemente  ...         NaN          NaN
# 2     01M015          P.S. 015 Roberto Clemente  ...         NaN          NaN
# 3     01M015          P.S. 015 Roberto Clemente  ...         NaN          NaN
# 4     01M015          P.S. 015 Roberto Clemente  ...         NaN          NaN
# ...      ...                                ...  ...         ...          ...
# 7383  84X730  Bronx Charter School for the Arts  ...         NaN          NaN
# 7384  84X730  Bronx Charter School for the Arts  ...         NaN          NaN
# 7385  84X730  Bronx Charter School for the Arts  ...         NaN          NaN
# 7386  84X730  Bronx Charter School for the Arts  ...         NaN          NaN
# 7387  84X730  Bronx Charter School for the Arts  ...         NaN          NaN
#
# [7388 rows x 84 columns]

# %%
location.head()
# Out:
#   ATS System Code Location Code  ... Unnamed: 43  Unnamed: 44
# 0          01M015          M015  ...         NaN          NaN
# 1          01M019          M019  ...         NaN          NaN
# 2          01M020          M020  ...         NaN          NaN
# 3          01M034          M034  ...         NaN          NaN
# 4          01M063          M063  ...         NaN          NaN
#
# [5 rows x 45 columns]

# %%
location_data = location_data.set_index("Location Name")

# %%
 location_data= pd.DataFrame(location_data.drop(axis=1, 
                                    columns=['Grade PK (Half Day & Full Day)',
                                            'Grade K', 
                                            'Grade 1', 
                                            'Grade 2', 
                                            'Grade 3', 
                                            'Grade 4', 
                                            'Grade 5', 
                                            'Grade 6', 
                                            'Grade 7', 
                                            'Grade 8', 
                                            'Grade 9', 
                                            'Grade 10', 
                                            'Grade 11', 
                                            'Grade 12', 
                                            'Unnamed: 21', 
                                            'Unnamed: 22',
                                            'Unnamed: 23',
                                            'Unnamed: 24',
                                            'Unnamed: 25',
                                            'Unnamed: 26',
                                            'Unnamed: 27',
                                            'Unnamed: 28',
                                            'Unnamed: 29',
                                            'Unnamed: 30',
                                            'Unnamed: 31',
                                            'Unnamed: 32',
                                            'Unnamed: 33',
                                            'Unnamed: 34',
                                            'Unnamed: 35',
                                            'Unnamed: 36',
                                            'Unnamed: 37',
                                            'Unnamed: 38',
                                            'Unnamed: 39', 
                                            'Unnamed: 40',
                                            'Unnamed: 41',
                                            'Unnamed: 42',
                                            'Unnamed: 43',
                                            'Unnamed: 44',
                                            'Status Description',
                                            'Building Code',
                                            'Managed By Name',
                                            'Location Code',
                                            'BEDS Number',
                                            'Location Type Description',
                                            'Grades Final',
                                            'Administrative District Location Code',
                                            'Administrative District Name']))

# %%
location_data_2017_18 = pd.DataFrame(location_data[location_data["Year"] =='2017-18'])

# %%
location_data_2017_18
# Out:
#                                              DBN  ... Administrative District Code
# Location Name                                     ...
# P.S. 015 Roberto Clemente                 01M015  ...                            1
# P.S. 019 Asher Levy                       01M019  ...                            1
# P.S. 020 Anna Silver                      01M020  ...                            1
# P.S. 034 Franklin D. Roosevelt            01M034  ...                            1
# P.S. 063 William McKinley                 01M063  ...                            1
# ...                                          ...  ...                          ...
# Family Life Academy Charter School        84X705  ...                           84
# Harriet Tubman Charter School             84X706  ...                           84
# Carl C. Icahn Charter School              84X717  ...                           84
# Bronx Charter School for Better Learning  84X718  ...                           84
# ...

# %%
def get_first_three(sequence):
  return sequence[:3]

# %%
location_data_2017_18['first_three'] = location_data_2017_18['DBN'].apply(get_first_three)

# %%
elementary = pd.DataFrame(location_data_2017_18[location_data_2017_18['Location Category Description'] == 'Elementary'])

# %%
k_eight = pd.DataFrame(location_data_2017_18[location_data_2017_18['Location Category Description'] == 'K-8'])
secondary = pd.DataFrame(location_data_2017_18[location_data_2017_18['Location Category Description'] == 'Secondary School'])
junior_high = pd.DataFrame(location_data_2017_18[location_data_2017_18['Location Category Description'] == 'Junior High-Intermediate-Middle'])
k_twelve = pd.DataFrame(location_data_2017_18[location_data_2017_18['Location Category Description'] == 'K-12 all grades'])
high_school = pd.DataFrame(location_data_2017_18[location_data_2017_18['Location Category Description'] == 'High school'])
early_childhood = pd.DataFrame(location_data_2017_18[location_data_2017_18['Location Category Description'] == 'Early Childhood'])
ungraded = pd.DataFrame(location_data_2017_18[location_data_2017_18['Location Category Description'] == 'Ungraded'])

# %%
# Elementary schools by Borough
brooklyn_elementary  = pd.DataFrame(elementary[elementary['City'] == 'BROOKLYN'])
queens_elementary = pd.DataFrame(elementary[elementary['City'] == 'QUEENS'])
manhattan_elementary = pd.DataFrame(elementary[elementary['City'] == 'MANHATTAN'])
bronx_elementary = pd.DataFrame(elementary[elementary['City'] == 'BRONX'])
statenisland_elementary = pd.DataFrame(elementary[elementary['City'] == 'STATEN ISLAND'])

# %%
# k-12 schools by Borough
brooklyn_k12  = pd.DataFrame(k_twelve[k_twelve['City'] == 'BROOKLYN'])
queens_k12 = pd.DataFrame(k_twelve[k_twelve['City'] == 'QUEENS'])
manhattan_k12 = pd.DataFrame(k_twelve[k_twelve['City'] == 'MANHATTAN'])
bronx_k12 = pd.DataFrame(k_twelve[k_twelve['City'] == 'BRONX'])
statenisland_k12 = pd.DataFrame(k_twelve[k_twelve['City'] == 'STATEN ISLAND'])

# %%
# k-8 schools by Borough 
brooklyn_k8  = pd.DataFrame(k_eight[k_eight['City'] == 'BROOKLYN'])
queens_k8 = pd.DataFrame(k_eight[k_eight['City'] == 'QUEENS'])
manhattan_k8 = pd.DataFrame(k_eight[k_eight['City'] == 'MANHATTAN'])
bronx_k8 = pd.DataFrame(k_eight[k_eight['City'] == 'BRONX'])
statenisland_k8 = pd.DataFrame(k_eight[k_eight['City'] == 'STATEN ISLAND'])

# %%
# Early Childhoood by Borough 
brooklyn_echildhood  = pd.DataFrame(early_childhood[early_childhood['City'] == 'BROOKLYN'])
queens_echildhood = pd.DataFrame(early_childhood[early_childhood['City'] == 'QUEENS'])
manhattan_echildhood = pd.DataFrame(early_childhood[early_childhood['City'] == 'MANHATTAN'])
bronx_echildhood = pd.DataFrame(early_childhood[early_childhood['City'] == 'BRONX'])
statenisland_echildhood = pd.DataFrame(early_childhood[early_childhood['City'] == 'STATEN ISLAND'])

# %%
# Junior High Schools by Borough
brooklyn_jhs  = pd.DataFrame(junior_high[junior_high['City'] == 'BROOKLYN'])
queens_jhs = pd.DataFrame(junior_high[junior_high['City'] == 'QUEENS'])
manhattan_jhs = pd.DataFrame(junior_high[junior_high['City'] == 'MANHATTAN'])
bronx_jhs = pd.DataFrame(junior_high[junior_high['City'] == 'BRONX'])
statenisland_jhs = pd.DataFrame(junior_high[junior_high['City'] == 'STATEN ISLAND'])

# %%
# Secondary Schools by Borough
brooklyn_secondary  = pd.DataFrame(secondary[secondary['City'] == 'BROOKLYN'])
queens_secondary = pd.DataFrame(secondary[secondary['City'] == 'QUEENS'])
manhattan_secondary = pd.DataFrame(secondary[secondary['City'] == 'MANHATTAN'])
bronx_secondary = pd.DataFrame(secondary[secondary['City'] == 'BRONX'])
statenisland_secondary = pd.DataFrame(secondary[secondary['City'] == 'STATEN ISLAND'])

# %%
# High Schools by Borough 
brooklyn_high_schools = pd.DataFrame(high_school[high_school['City'] == 'BROOKLYN'])
queens_high_schools= pd.DataFrame(high_school[high_school['City'] == 'QUEENS'])
manhattan_high_schools= pd.DataFrame(high_school[high_school['City'] == 'MANHATTAN'])
bronx_high_schools= pd.DataFrame(high_school[high_school['City'] == 'BRONX'])
statenisland_high_schools= pd.DataFrame(high_school[high_school['City'] == 'STATEN ISLAND'])

# %%
# Brooklyn Elementary Schools by District 
district_13_elem = pd.DataFrame(elementary[elementary['first_three'] == '13K'])
district_14_elem = pd.DataFrame(elementary[elementary['first_three'] == '14K'])
district_15_elem = pd.DataFrame(elementary[elementary['first_three'] == '15K'])
district_16_elem = pd.DataFrame(elementary[elementary['first_three'] == '16K'])
district_17_elem = pd.DataFrame(elementary[elementary['first_three'] == '17K'])
district_18_elem = pd.DataFrame(elementary[elementary['first_three'] == '18K'])
district_19_elem = pd.DataFrame(elementary[elementary['first_three'] == '19K'])
district_20_elem = pd.DataFrame(elementary[elementary['first_three'] == '20K'])
district_21_elem = pd.DataFrame(elementary[elementary['first_three'] == '21K'])
district_22_elem = pd.DataFrame(elementary[elementary['first_three'] == '22K'])
district_23_elem = pd.DataFrame(elementary[elementary['first_three'] == '23K'])
district_84k_elem = pd.DataFrame(elementary[elementary['first_three'] == '84K'])

# %%
# Brooklyn High Schools by District
district_13_highschools= pd.DataFrame(high_school[high_school['first_three'] == '13K'])
district_14_highschools= pd.DataFrame(high_school[high_school['first_three'] == '14K'])
district_15_highschools= pd.DataFrame(high_school[high_school['first_three'] == '15K'])
district_16_highschools= pd.DataFrame(high_school[high_school['first_three'] == '16K'])
district_17_highschools= pd.DataFrame(high_school[high_school['first_three'] == '17K'])
district_18_highschools= pd.DataFrame(high_school[high_school['first_three'] == '18K'])
district_19_highschools= pd.DataFrame(high_school[high_school['first_three'] == '19K'])
district_20_highschools= pd.DataFrame(high_school[high_school['first_three'] == '20K'])
district_21_highschools= pd.DataFrame(high_school[high_school['first_three'] == '21K'])
district_22_highschools= pd.DataFrame(high_school[high_school['first_three'] == '22K'])
district_23_highschools= pd.DataFrame(high_school[high_school['first_three'] == '23K'])
district_84k_highschools= pd.DataFrame(high_school[high_school['first_three'] == '84K'])

# %%
# Manhattan Elementary Schools by District
district_01_elem = pd.DataFrame(elementary[elementary['first_three'] == '01M'])
district_02_elem = pd.DataFrame(elementary[elementary['first_three'] == '02M'])
district_03_elem = pd.DataFrame(elementary[elementary['first_three'] == '03M'])
district_04_elem = pd.DataFrame(elementary[elementary['first_three'] == '04M'])
district_05_elem = pd.DataFrame(elementary[elementary['first_three'] == '05M'])
district_06_elem = pd.DataFrame(elementary[elementary['first_three'] == '06M'])
district_84m_elem = pd.DataFrame(elementary[elementary['first_three'] == '84M'])

# Bronx Elementary Schools by District
district_07_elem = pd.DataFrame(elementary[elementary['first_three'] == '07X'])
district_08_elem = pd.DataFrame(elementary[elementary['first_three'] == '08X'])
district_09_elem = pd.DataFrame(elementary[elementary['first_three'] == '09X'])
district_10_elem = pd.DataFrame(elementary[elementary['first_three'] == '10X'])
district_11_elem = pd.DataFrame(elementary[elementary['first_three'] == '11X'])
district_12_elem = pd.DataFrame(elementary[elementary['first_three'] == '12X'])
district_84x_elem = pd.DataFrame(elementary[elementary['first_three'] == '84X'])

# Queens Elementary Schools by District 
district_24_elem = pd.DataFrame(elementary[elementary['first_three'] == '24Q'])
district_25_elem = pd.DataFrame(elementary[elementary['first_three'] == '25Q'])
district_26_elem = pd.DataFrame(elementary[elementary['first_three'] == '26Q'])
district_27_elem = pd.DataFrame(elementary[elementary['first_three'] == '27Q'])
district_28_elem = pd.DataFrame(elementary[elementary['first_three'] == '28Q'])
district_29_elem = pd.DataFrame(elementary[elementary['first_three'] == '29Q'])
district_30_elem = pd.DataFrame(elementary[elementary['first_three'] == '30Q'])
district_84q_elem = pd.DataFrame(elementary[elementary['first_three'] == '84Q'])

# %%
# Manhattan High Schools by District
district_01_highschools= pd.DataFrame(high_school[high_school['first_three'] == '01M'])
district_02_highschools= pd.DataFrame(high_school[high_school['first_three'] == '02M'])
district_03_highschools= pd.DataFrame(high_school[high_school['first_three'] == '03M'])
district_04_highschools= pd.DataFrame(high_school[high_school['first_three'] == '04M'])
district_05_highschools= pd.DataFrame(high_school[high_school['first_three'] == '05M'])
district_06_highschools= pd.DataFrame(high_school[high_school['first_three'] == '06M'])
district_84m_highschools= pd.DataFrame(high_school[high_school['first_three'] == '84M'])

# Bronx High Schools by District
district_07_highschools= pd.DataFrame(high_school[high_school['first_three'] == '07X'])
district_08_highschools= pd.DataFrame(high_school[high_school['first_three'] == '08X'])
district_09_highschools= pd.DataFrame(high_school[high_school['first_three'] == '09X'])
district_10_highschools= pd.DataFrame(high_school[high_school['first_three'] == '10X'])
district_11_highschools= pd.DataFrame(high_school[high_school['first_three'] == '11X'])
district_12_highschools= pd.DataFrame(high_school[high_school['first_three'] == '12X'])
district_84x_highschools= pd.DataFrame(high_school[high_school['first_three'] == '84X'])

# Queens High Schools by District 
district_24_highschools= pd.DataFrame(high_school[high_school['first_three'] == '24Q'])
district_25_highschools= pd.DataFrame(high_school[high_school['first_three'] == '25Q'])
district_26_highschools= pd.DataFrame(high_school[high_school['first_three'] == '26Q'])
district_27_highschools= pd.DataFrame(high_school[high_school['first_three'] == '27Q'])
district_28_highschools= pd.DataFrame(high_school[high_school['first_three'] == '28Q'])
district_29_highschools= pd.DataFrame(high_school[high_school['first_three'] == '29Q'])
district_30_highschools= pd.DataFrame(high_school[high_school['first_three'] == '30Q'])
district_84q_highschools= pd.DataFrame(high_school[high_school['first_three'] == '84Q'])

# %%
# Brooklyn Junior High Schools by District
district_13_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '13K'])
district_14_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '14K'])
district_15_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '15K'])
district_16_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '16K'])
district_17_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '17K'])
district_18_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '18K'])
district_19_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '19K'])
district_20_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '20K'])
district_21_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '21K'])
district_22_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '22K'])
district_23_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '23K'])
district_84k_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '84K'])

# Manhattan Junior High Schools by District
district_01_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '01M'])
district_02_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '02M'])
district_03_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '03M'])
district_04_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '04M'])
district_05_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '05M'])
district_06_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '06M'])
district_84m_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '84M'])

# Bronx Junior High Schools by District
district_07_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '07X'])
district_08_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '08X'])
district_09_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '09X'])
district_10_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '10X'])
district_11_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '11X'])
district_12_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '12X'])
district_84x_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '84X'])

# Queens Junior High Schools by District 
district_24_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '24Q'])
district_25_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '25Q'])
district_26_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '26Q'])
district_27_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '27Q'])
district_28_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '28Q'])
district_29_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '29Q'])
district_30_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '30Q'])
district_84q_jhs= pd.DataFrame(junior_high[junior_high['first_three'] == '84Q'])

# %%
# Brooklyn K-8 High Schools by District
district_13_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '13K'])
district_14_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '14K'])
district_15_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '15K'])
district_16_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '16K'])
district_17_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '17K'])
district_18_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '18K'])
district_19_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '19K'])
district_20_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '20K'])
district_21_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '21K'])
district_22_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '22K'])
district_23_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '23K'])
district_84k_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '84K'])

# Manhattan K-8 High Schools by District
district_01_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '01M'])
district_02_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '02M'])
district_03_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '03M'])
district_04_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '04M'])
district_05_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '05M'])
district_06_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '06M'])
district_84m_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '84M'])

# Bronx K-8 High Schools by District
district_07_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '07X'])
district_08_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '08X'])
district_09_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '09X'])
district_10_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '10X'])
district_11_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '11X'])
district_12_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '12X'])
district_84x_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '84X'])

# Queens K-8 High Schools by District 
district_24_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '24Q'])
district_25_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '25Q'])
district_26_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '26Q'])
district_27_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '27Q'])
district_28_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '28Q'])
district_29_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '29Q'])
district_30_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '30Q'])
district_84q_k8= pd.DataFrame(k_eight[k_eight['first_three'] == '84Q'])

# %%
# Brooklyn k-12 High Schools by District
district_13_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '13K'])
district_14_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '14K'])
district_15_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '15K'])
district_16_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '16K'])
district_17_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '17K'])
district_18_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '18K'])
district_19_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '19K'])
district_20_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '20K'])
district_21_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '21K'])
district_22_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '22K'])
district_23_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '23K'])
district_84k_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '84K'])

# Manhattan k-12 High Schools by District
district_01_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '01M'])
district_02_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '02M'])
district_03_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '03M'])
district_04_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '04M'])
district_05_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '05M'])
district_06_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '06M'])
district_84m_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '84M'])

# Bronx k-12 High Schools by District
district_07_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '07X'])
district_08_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '08X'])
district_09_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '09X'])
district_10_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '10X'])
district_11_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '11X'])
district_12_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '12X'])
district_84x_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '84X'])

# Queens k-12 Schools by District 
district_24_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '24Q'])
district_25_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '25Q'])
district_26_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '26Q'])
district_27_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '27Q'])
district_28_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '28Q'])
district_29_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '29Q'])
district_30_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '30Q'])
district_84q_k12= pd.DataFrame(k_twelve[k_twelve['first_three'] == '84Q'])

# %%
# Brooklyn Secondary High Schools by District
district_13_secondary= pd.DataFrame(secondary[secondary['first_three'] == '13K'])
district_14_secondary= pd.DataFrame(secondary[secondary['first_three'] == '14K'])
district_15_secondary= pd.DataFrame(secondary[secondary['first_three'] == '15K'])
district_16_secondary= pd.DataFrame(secondary[secondary['first_three'] == '16K'])
district_17_secondary= pd.DataFrame(secondary[secondary['first_three'] == '17K'])
district_18_secondary= pd.DataFrame(secondary[secondary['first_three'] == '18K'])
district_19_secondary= pd.DataFrame(secondary[secondary['first_three'] == '19K'])
district_20_secondary= pd.DataFrame(secondary[secondary['first_three'] == '20K'])
district_21_secondary= pd.DataFrame(secondary[secondary['first_three'] == '21K'])
district_22_secondary= pd.DataFrame(secondary[secondary['first_three'] == '22K'])
district_23_secondary= pd.DataFrame(secondary[secondary['first_three'] == '23K'])
district_84k_secondary= pd.DataFrame(secondary[secondary['first_three'] == '84K'])

# Manhattan Secondary High Schools by District
district_01_secondary= pd.DataFrame(secondary[secondary['first_three'] == '01M'])
district_02_secondary= pd.DataFrame(secondary[secondary['first_three'] == '02M'])
district_03_secondary= pd.DataFrame(secondary[secondary['first_three'] == '03M'])
district_04_secondary= pd.DataFrame(secondary[secondary['first_three'] == '04M'])
district_05_secondary= pd.DataFrame(secondary[secondary['first_three'] == '05M'])
district_06_secondary= pd.DataFrame(secondary[secondary['first_three'] == '06M'])
district_84m_secondary= pd.DataFrame(secondary[secondary['first_three'] == '84M'])

# Bronx Secondary High Schools by District
district_07_secondary= pd.DataFrame(secondary[secondary['first_three'] == '07X'])
district_08_secondary= pd.DataFrame(secondary[secondary['first_three'] == '08X'])
district_09_secondary= pd.DataFrame(secondary[secondary['first_three'] == '09X'])
district_10_secondary= pd.DataFrame(secondary[secondary['first_three'] == '10X'])
district_11_secondary= pd.DataFrame(secondary[secondary['first_three'] == '11X'])
district_12_secondary= pd.DataFrame(secondary[secondary['first_three'] == '12X'])
district_84x_secondary= pd.DataFrame(secondary[secondary['first_three'] == '84X'])

# Queens Secondary High Schools by District 
district_24_secondary= pd.DataFrame(secondary[secondary['first_three'] == '24Q'])
district_25_secondary= pd.DataFrame(secondary[secondary['first_three'] == '25Q'])
district_26_secondary= pd.DataFrame(secondary[secondary['first_three'] == '26Q'])
district_27_secondary= pd.DataFrame(secondary[secondary['first_three'] == '27Q'])
district_28_secondary= pd.DataFrame(secondary[secondary['first_three'] == '28Q'])
district_29_secondary= pd.DataFrame(secondary[secondary['first_three'] == '29Q'])
district_30_secondary= pd.DataFrame(secondary[secondary['first_three'] == '30Q'])
district_84q_secondary= pd.DataFrame(secondary[secondary['first_three'] == '84Q'])

# %%
print(district_13_elem['School Name'].count())
print(district_14_elem['School Name'].count())
print(district_15_elem['School Name'].count())
print(district_16_elem['School Name'].count())
print(district_17_elem['School Name'].count())
print(district_18_elem['School Name'].count())
print(district_19_elem['School Name'].count())
print(district_20_elem['School Name'].count())
print(district_21_elem['School Name'].count())
print(district_22_elem['School Name'].count())
print(district_23_elem['School Name'].count())
print(district_84_elem['School Name'].count())
# Out:
# 19
# 19
# 23
# 12
# 13
# 11
# 17
# 23
# 14
# 23
# 4
# 10

# %%
plt.style.use('fivethirtyeight')

# %%
district_13_elem['Total Enrollment'].plot(kind='bar', figsize=(15,5));

# %%
district_20_elem['Total Enrollment'].plot(kind='bar', figsize=(15,5));

# %%
district_23_elem['Total Enrollment'].plot(kind='bar', figsize=(15,5));

# %%
#district_13_elem['% White'].plot(kind='bar', figsize=(15,5), color='r')
district_14_elem['% White'].plot(kind='bar', figsize=(15,5), color='b')
plt.show();

# %%
district_13_elem['% Hispanic'].plot(kind='line', figsize=(15,5), color='r')
district_13_elem['% White'].plot(kind='line', figsize=(15,5), color='b')
district_13_elem['% Black'].plot(kind='line', figsize=(15,5), color='g')
district_13_elem['% Asian'].plot(kind='line', figsize=(15,5), color='y')
plt.show();

# %%
district_17_elem['# Black'].plot(kind='line', figsize=(15, 5), color = 'g')
district_17_elem['# White'].plot(kind='line', figsize=(15, 5), color = 'w')
district_17_elem['# Asian'].plot(kind='line', figsize=(15, 5), color = 'y')
district_17_elem['# Hispanic'].plot(kind='line', figsize=(15, 5), color = 'r');

# %%
district_19_elem = district_19_elem.set_index('School Name')

# %%
district_19_elem.head()
# Out:
#                                 DBN  ... first_three
# School Name                          ...
# P.S. 007 Abraham Lincoln     19K007  ...         19K
# P.S. 013 Roberto Clemente    19K013  ...         19K
# P.S. 065                     19K065  ...         19K
# P.S. 108 Sal Abbracciamento  19K108  ...         19K
# P.S. 149 Danny Kaye          19K149  ...         19K
#
# [5 rows x 36 columns]

# %%
district_19_elem['Total Enrollment'].plot(kind='bar', figsize=(20, 5), color = 'm');

# %%
district_25_elem['% Black'].plot(kind='line', figsize=(20, 5), color = 'black')
district_25_elem['% Hispanic'].plot(kind='line', figsize=(20, 5), color = 'r');

# %%
brooklyn_elementary['School Name'].unique()
# Out:
# array(['P.S. 003 The Bedford Village', 'P.S. 008 Robert Fulton',
#        'P.S. 009 Teunis G. Bergen', 'P.S. 011 Purvis J. Behan',
#        'P.S. 020 Clinton Hill', 'P.S. 044 Marcus Garvey',
#        'P.S. 046 Edward C. Blum', 'P.S. 054 Samuel C. Barnes',
#        'P.S. 056 Lewis H. Latimer', 'P.S. 067 Charles A. Dorsey',
#        'P.S. 093 William H. Prescott', 'P.S. 256 Benjamin Banneker',
#        'P.S. 270 Johann DeKalb', 'P.S. 282 Park Slope',
#        'P.S. 287 Bailey K. Ashford', 'Satellite East Middle School',
#        'P.S. 305 Dr. Peter Ray', 'P.S. 307 Daniel Hale Williams',
#        'P.S. 016 Leonard Dunkly', 'P.S. 017 Henry D. Woodworth',
#        'P.S. 018 Edward Bush', 'P.S. 023 Carter G. Woodson',
#        'P.S. 031 Samuel F. Dupont', 'P.S. 034 Oliver H. Perry',
#        'P.S. 059 William Floyd', 'P.S. 084 Jose De Diego', 'P.S. 024',
#        'P.S. 110 The Monitor', 'P.S. 120 Carlos Tapia',
#        'P.S. 132 The Conselyea School', 'P.S. 147 Isaac Remsen',
# ...

# %%
district_84_elem['School Name'].unique()
# Out:
# array(['Williamsburg Collegiate Charter School',
#        'Achievement First Crown Heights Charter School',
#        'KIPP AMP Charter School', 'Hellenic Classical Charter School',
#        'Community Roots Charter School', 'La Cima Charter School',
#        'PAVE Academy Charter School', 'Brooklyn Charter School',
#        'Community Partnership Charter School',
#        'Brooklyn Excelsior Charter School'], dtype=object)

# %%
district_84_elem['% White'].plot(kind='line', figsize=(15, 5), color='g');

# %%
sns.barplot(x='% Black', y= '% White', data=district_01_jhs);

# %%
sns.barplot(x="Total Enrollment", y = "# Hispanic", data=district_25_jhs);

# %%
sns.scatterplot(x="% Black", y = "% White", data=district_25_elem);

# %%
sns.scatterplot(x="% Hispanic", y = "% Asian", data=district_25_elem);

# %%
sns.scatterplot(x="% Black", y = "% Hispanic", data=district_25_elem);

# %%
sns.scatterplot(x="% Black", y = "% White", data=district_17_elem);

# %%
sns.scatterplot(x="% Hispanic", y = "% Asian", data=district_17_elem);

# %%
sns.scatterplot(x="% Black", y = "% White", data=district_07_elem);

# %%
sns.kdeplot(district_01_highschools['# Asian'], district_01_jhs['# Asian']);

# %%
sns.kdeplot(district_01_highschools['% Black'], district_01_highschools['% White']);

# %%
sns.kdeplot(district_25_jhs['% Asian'], district_25_jhs['% White']);

# %%
district_02_highschools['% Black'].mean()
# Out:
# 24.687999999999988

# %%
district_02_highschools['% White'].mean()
# Out:
# 10.578

# %%
district_02_highschools['% Hispanic'].mean()
# Out:
# 48.37400000000002

# %%
district_02_highschools['% Asian'].mean()
# Out:
# 13.19
